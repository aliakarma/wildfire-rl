# %%
from google.colab import drive

drive.mount('/content/drive')

# %%
import os

BASE = "/content/drive/MyDrive/PyroRL_Saudi_Project/datasets"

folders = [
    "saudi_eastern_province/raw/firms/active_fire",
    "saudi_eastern_province/processed/fire",
    "saudi_eastern_province/grids/32x32",
    "saudi_eastern_province/grids/64x64"
]

for folder in folders:
    os.makedirs(os.path.join(BASE, folder), exist_ok=True)

print("FIRMS folders created.")

# %%
from google.colab import files

uploaded = files.upload()

# %%
import shutil
import os

BASE = "/content/drive/MyDrive/PyroRL_Saudi_Project/datasets"
firms_dir = os.path.join(BASE, "saudi_eastern_province/raw/firms/active_fire")

SOURCE_FILE = "fires.csv"

DEST_FILE = f"{firms_dir}/saudi_firms_june_2025.csv"

shutil.move(SOURCE_FILE, DEST_FILE)

print("FIRMS CSV moved successfully.")

# %%
os.listdir(firms_dir)

# %%
import pandas as pd

firms_path = f"{firms_dir}/saudi_firms_june_2025.csv"

df = pd.read_csv(firms_path)

df.head()

# %%
print(df.columns)

# %%
df = df.dropna(subset=['latitude', 'longitude', 'frp'])

# %%
print(df['confidence'].unique()[:20])

# %%
df = df[df['confidence'] != 'low']

# %%
print("Remaining fire detections:", len(df))

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(8,8))

plt.scatter(
    df['longitude'],
    df['latitude'],
    s=5,
    c=df['frp'],
    cmap='hot'
)

plt.colorbar(label='FRP')

plt.title("Saudi FIRMS Fire Hotspots")

plt.xlabel("Longitude")
plt.ylabel("Latitude")

plt.show()

# %%
LAT_MIN = 23.5
LAT_MAX = 28.5

LON_MIN = 45.5
LON_MAX = 50.5

# %%
import numpy as np

GRID_SIZE = 32

fire_grid_32 = np.zeros((GRID_SIZE, GRID_SIZE))

# %%
for _, row in df.iterrows():

    lat = row['latitude']
    lon = row['longitude']

    frp = row['frp']

    x = int(
        (lon - LON_MIN) /
        (LON_MAX - LON_MIN)
        * (GRID_SIZE - 1)
    )

    y = int(
        (lat - LAT_MIN) /
        (LAT_MAX - LAT_MIN)
        * (GRID_SIZE - 1)
    )

    if 0 <= x < GRID_SIZE and 0 <= y < GRID_SIZE:

        fire_grid_32[y, x] += frp

# %%
if fire_grid_32.max() > 0:

    fire_grid_32 = (
        fire_grid_32 /
        fire_grid_32.max()
    )

# %%
plt.figure(figsize=(6,6))

plt.imshow(
    fire_grid_32,
    cmap='hot'
)

plt.title("32x32 PyroRL Fire Grid")

plt.colorbar()

plt.show()

# %%
save_path = "/content/drive/MyDrive/PyroRL_Saudi_Project/datasets/saudi_eastern_province/grids/32x32/fire.npy"

np.save(save_path, fire_grid_32)

print("32x32 fire grid saved.")

# %%
print(fire_grid_32.shape)

# %%
GRID_SIZE = 64

fire_grid_64 = np.zeros((GRID_SIZE, GRID_SIZE))

# %%
for _, row in df.iterrows():

    lat = row['latitude']
    lon = row['longitude']

    frp = row['frp']

    x = int(
        (lon - LON_MIN) /
        (LON_MAX - LON_MIN)
        * (GRID_SIZE - 1)
    )

    y = int(
        (lat - LAT_MIN) /
        (LAT_MAX - LAT_MIN)
        * (GRID_SIZE - 1)
    )

    if 0 <= x < GRID_SIZE and 0 <= y < GRID_SIZE:

        fire_grid_64[y, x] += frp

# %%
if fire_grid_64.max() > 0:

    fire_grid_64 = (
        fire_grid_64 /
        fire_grid_64.max()
    )

# %%
save_path = "/content/drive/MyDrive/PyroRL_Saudi_Project/datasets/saudi_eastern_province/grids/64x64/fire.npy"

np.save(save_path, fire_grid_64)

print("64x64 fire grid saved.")
